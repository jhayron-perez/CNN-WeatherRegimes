# %%
import copy
import glob
import pickle
import warnings
from datetime import datetime, timedelta
from itertools import product
import joblib
import os

import cartopy
import cartopy.crs as ccrs
import cartopy.feature
import cartopy.feature as cfeature
import cartopy.feature as cf
import cartopy.io.shapereader as shpreader
import matplotlib as mpl
import matplotlib.path as mpath
import matplotlib.pyplot as plt
import numpy as np
# np.random.seed(42)
import pandas as pd
import shapely.geometry as sgeom
import xarray as xr
from scipy import stats
from scipy.spatial.distance import cdist
from shapely import geometry
from sklearn import metrics
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# import cluster_analysis, narm_analysis, som_analysis

# %%
dic_metrics = np.load('/glade/work/jhayron/Weather_Regimes/models/CNN/metrics/dic_metrics_v3.npy',
                     allow_pickle=True)[()]

# %%
week1_wr = pd.read_csv('/glade/work/jhayron/Weather_Regimes/weekly_wr/week1_wr_v3.csv',\
                      index_col = 0, parse_dates = True)
week2_wr = pd.read_csv('/glade/work/jhayron/Weather_Regimes/weekly_wr/week2_wr_v3.csv',\
                      index_col = 0, parse_dates = True)
week3_wr = pd.read_csv('/glade/work/jhayron/Weather_Regimes/weekly_wr/week3_wr_v3.csv',\
                      index_col = 0, parse_dates = True)
week4_wr = pd.read_csv('/glade/work/jhayron/Weather_Regimes/weekly_wr/week4_wr_v3.csv',\
                      index_col = 0, parse_dates = True)
week5_wr = pd.read_csv('/glade/work/jhayron/Weather_Regimes/weekly_wr/week5_wr_v3.csv',\
                      index_col = 0, parse_dates = True)
week6_wr = pd.read_csv('/glade/work/jhayron/Weather_Regimes/weekly_wr/week6_wr_v3.csv',\
                      index_col = 0, parse_dates = True)
week7_wr = pd.read_csv('/glade/work/jhayron/Weather_Regimes/weekly_wr/week7_wr_v3.csv',\
                      index_col = 0, parse_dates = True)
week8_wr = pd.read_csv('/glade/work/jhayron/Weather_Regimes/weekly_wr/week8_wr_v3.csv',\
                      index_col = 0, parse_dates = True)
week9_wr = pd.read_csv('/glade/work/jhayron/Weather_Regimes/weekly_wr/week9_wr_v3.csv',\
                      index_col = 0, parse_dates = True)

df_wr = pd.concat([week1_wr,week2_wr,week3_wr,week4_wr,week5_wr,week6_wr,week7_wr,week8_wr,week9_wr],axis=1)
df_wr.columns = ['week1','week2','week3','week4','week5','week6','week7','week8','week9']

df_wr_2 = pd.read_csv('/glade/work/jhayron/Weather_Regimes/weekly_wr/weekly_wr_mean_geop_v3.csv',
                     index_col=0,parse_dates=True)

df_wr_2 = df_wr_2.dropna()
df_wr = df_wr.dropna()

# %%
variables = ['z500','olr', 'sst', 'u10', 'sm_region', 'st_region']
name_var = ['z500','olr', 'sst', 'u10', 'sm', 'st']
units = ['m2/s2','J/m2','K','m/s','m3/m3','K']

# %% [markdown]
# # Figures general metrics

# %%
colors = ['royalblue','blueviolet','red','gold','limegreen','coral']

# %%
plt.figure(figsize=(8,5))
for i in range(len(variables)):
    plt.plot(np.arange(8),dic_metrics[variables[i]].acc_model, color=colors[i],
             label=variables[i].upper().replace('_','-'))
    plt.scatter(np.arange(8),dic_metrics[variables[i]].acc_model,color=colors[i])
plt.plot(np.arange(8),dic_metrics[variables[i]].acc_persistence,label='Persistence',color='k')
plt.scatter(np.arange(8),dic_metrics[variables[i]].acc_persistence,color='k')
plt.legend(ncol=2,fontsize=11)
plt.ylabel('Percentage of accurate predictions [%]\nTesting Sample',fontsize=12)
plt.xticks(np.arange(8),['Week 1','Week 2','Week 3','Week 4','Week 5','Week 6','Week 7','Week 8'],fontsize=12)
plt.xlabel('Lead time',fontsize=12)
plt.yticks(fontsize=12)
path_figures = '/glade/u/home/jhayron/WeatherRegimes/Figures/'
plt.savefig(f'{path_figures}Accuracy_CNN_Variables_v2.png',bbox_inches='tight')

# %%
plt.figure(figsize=(8,5))
for i in range(len(variables)):
    plt.plot(np.arange(8),dic_metrics[variables[i]].acc_model - dic_metrics[variables[i]].acc_persistence, color=colors[i],
             label=variables[i].upper().replace('_','-'))
    plt.scatter(np.arange(8),dic_metrics[variables[i]].acc_model - dic_metrics[variables[i]].acc_persistence,color=colors[i])
# plt.plot(np.arange(8),dic_metrics[variable].acc_persistence,label='Persistence',color='k')
# plt.scatter(np.arange(8),dic_metrics[variable].acc_persistence,color='k')
plt.legend(ncol=2,fontsize=11)
plt.ylabel('Percentage of accurate predictions [%]\nTesting Sample',fontsize=12)
plt.xticks(np.arange(8),['Week 1','Week 2','Week 3','Week 4','Week 5','Week 6','Week 7','Week 8'],fontsize=12)
plt.xlabel('Lead time',fontsize=12)
plt.yticks(fontsize=12)
path_figures = '/glade/u/home/jhayron/WeatherRegimes/Figures/'
plt.savefig(f'{path_figures}Accuracy_CNN_Variables_Relative_v2.png',bbox_inches='tight')

# %%
plt.figure(figsize=(8,5))
for i in range(len(variables)):
    plt.plot(np.arange(8),dic_metrics[variables[i]].loss_model, color=colors[i],
             label=variables[i].upper().replace('_','-'))
    plt.scatter(np.arange(8),dic_metrics[variables[i]].loss_model,color=colors[i])
# plt.plot(np.arange(8),dic_metrics[variable].loss_persistence,label='Persistence',color='k')
# plt.scatter(np.arange(8),dic_metrics[variable].loss_persistence,color='k')
plt.legend(ncol=2,fontsize=11)
plt.ylabel('Categorical Cross-Entropy\nTesting Sample',fontsize=12)
plt.xticks(np.arange(8),['Week 1','Week 2','Week 3','Week 4','Week 5','Week 6','Week 7','Week 8'],fontsize=12)
plt.xlabel('Lead time',fontsize=12)
plt.yticks(fontsize=12)
plt.ylim(1.25,1.45)
# plt.xlim(0,7)
path_figures = '/glade/u/home/jhayron/WeatherRegimes/Figures/'
plt.savefig(f'{path_figures}Loss_CNN_Variables_v2.png',bbox_inches='tight')

# %% [markdown]
# # Metrics starting from different regimes

# %%
import keras
from keras.models import Sequential,Model
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, AveragePooling2D
from keras.utils import to_categorical
from keras.layers import LeakyReLU
from keras.layers import ReLU
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint

from sklearn.model_selection import train_test_split
from sklearn.metrics import log_loss
from sklearn.metrics import accuracy_score
# import visualkeras
# import tensorflow as tf

# ## GLOBAL SEED ##    
# np.random.seed(42)
# tf.random.set_seed(42)

# %%
def create_model(activation_conv = ReLU()):
    num_classes = 4
    # alpha=0.01
    ks = 3
    ps = 5
    nfilters=64
    padding_type = 'valid'
    model = Sequential()
    model.add(Conv2D(nfilters, kernel_size=(ks, ks),activation=activation_conv,
        input_shape=X_train.shape[1:],padding=padding_type))
    model.add(AveragePooling2D((ps, ps),padding=padding_type))
    
    model.add(Conv2D(nfilters*2, (ks, ks), activation=activation_conv,padding=padding_type))
    model.add(AveragePooling2D(pool_size=(ps, ps),padding=padding_type))
    

    model.add(Flatten())
    model.add(Dense(nfilters*2, activation=activation_conv))                
    model.add(Dense(num_classes, activation='softmax'))

    model.compile(loss=keras.losses.categorical_crossentropy, 
        optimizer=keras.optimizers.Adam(lr=0.0001),metrics=['accuracy'])
    return model

# %%
dic_vars = {}
for var_short, variable,unit in zip(name_var,variables,units):
# for var_short, variable,unit in zip(['sst'],['sst'],['K']):
    path_w_anoms = '/glade/work/jhayron/Weather_Regimes/weekly_anomalies/'
    week1_anoms = xr.open_dataset(f'{path_w_anoms}week1_{variable}_anoms_v3.nc')
    # week1_anoms = week1_anoms.sel(time=df_wr_2.index)
    if variable=='z500':
        week1_anoms = week1_anoms.where(week1_anoms.lat>-30,drop=True)
    # week1_anoms = week1_anoms.sel(time=df_wr.index)
    week1_anoms = week1_anoms.sel(time=df_wr_2.index)
    dic_vars[variable] = week1_anoms
    
#     ##########PLOT#####################
#     fig = plt.figure(figsize=(9,7))
#     ax = fig.add_subplot(111,projection=ccrs.PlateCarree(central_longitude=-90+360))
    
#     vmax = np.round(np.percentile(abs(week1_anoms[f'{var_short}_anomalies'].values[0]),100),0)
#     vmin = -np.round(np.percentile(abs(week1_anoms[f'{var_short}_anomalies'].values[0]),100),0)
#     # print(vmax,vmin)
#     cs = plt.pcolormesh(week1_anoms.lon,week1_anoms.lat,\
#         week1_anoms[f'{var_short}_anomalies'].values[0],cmap='seismic',
#         transform=ccrs.PlateCarree(),vmin=vmin,vmax=vmax)
#     ax.coastlines(resolution='110m', color='k', linewidth=0.75, zorder=10)
#     ax.margins(x=0, y=0)

#     # ax.set_extent([-179, 179, 10, 90], crs=ccrs.PlateCarree())
#     if variable!='st':
#         plt.title(variable.upper().replace('_','-'))
#     else:
#         plt.title(variable.upper().replace('_','-').replace('ST','TS'))
#     if 'region' in variable:
#         cbar_ax = fig.add_axes([0.25, 0.19, 0.5, 0.0175])
#     else:
#         cbar_ax = fig.add_axes([0.25, 0.3, 0.5, 0.0175])
#     # ticks_1 = [-80, -40, 0, 40, 80]
#     cbar = fig.colorbar(cs, cax=cbar_ax,
#                         orientation='horizontal', extend='both')
#     cbar.ax.tick_params(labelsize=14)
#     cbar.set_label(unit, fontsize=14)
#     plt.savefig(f'/glade/u/home/jhayron/WeatherRegimes/Figures/MapsVariables/{variable}_anomalies_v2.png',bbox_inches='tight')
#     plt.close('all')

# %%
path_models = '/glade/work/jhayron/Weather_Regimes/models/CNN/weights_variables_v3/'

# %%
dic_loss_model = {}
dic_acc_model = {}
dic_loss_persistence = {}
dic_acc_persistence = {}

for var_short, variable in zip(name_var,variables):
    print('********************************************************************************************')
    print(variable)
    print('********************************************************************************************')
    loss_weeks_model = np.zeros([8,4])
    loss_weeks_persistence = np.zeros([8,4])
    acc_weeks_model = np.zeros([8,4])
    acc_weeks_persistence = np.zeros([8,4])

    for iweek,week in enumerate(['week2','week3','week4','week5','week6','week7','week8','week9']):
        print(week)
        #### ORGANIZE DATA ####
        week_output_wr = df_wr_2[week].values.astype(int)
        # Make Y categorical
        serie_wr_categorical = to_categorical(week_output_wr,num_classes=4)
        
        week1_anoms = copy.deepcopy(dic_vars[variable])
        
        # # Scale by min-max
        Min = week1_anoms[f'{var_short}_anomalies'].min(dim='time')
        Max = week1_anoms[f'{var_short}_anomalies'].max(dim='time')
        scaled_x = (week1_anoms[f'{var_short}_anomalies']) / (Max - Min)

        indices = np.arange(len(serie_wr_categorical))
        #Reshape X
        scaled_x = scaled_x.data.reshape(-1, scaled_x.shape[1],scaled_x.shape[2], 1)

        indices_train = np.where(df_wr_2.week2.index.year<=2001)[0]
        indices_val = np.where((df_wr_2.week2.index.year>2001)&(df_wr_2.week2.index.year<=2010))[0]
        indices_test = np.where(df_wr_2.week2.index.year>2010)[0]

        X_test = scaled_x[indices_test]
        y_test = serie_wr_categorical[indices_test]

        X_train = scaled_x[indices_train]
        y_train = serie_wr_categorical[indices_train]

        X_val = scaled_x[indices_val]
        y_val = serie_wr_categorical[indices_val]

        wr_persistence = df_wr_2.week1.values.astype(int)[indices_test]
        serie_wr_persistence_categorical = to_categorical(wr_persistence)

        #### TRAIN ####

        keras.backend.clear_session()
        model = create_model()
#         batch_size = 128
#         epochs = 200

#         earlystop = EarlyStopping(monitor='val_loss', patience=5)
#         try:
#             os.mkdir(f'{path_models}{variable}')
#         except: pass
        filepath = f'{path_models}{variable}/model_{week}_v3.h5'
        # checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=0, save_best_only=True, 
        #                              mode='auto',save_weights_only=False)
        # model.fit(X_train, y_train, batch_size=batch_size,\
        #     epochs=epochs,verbose=0,validation_data=(X_val, y_val), callbacks=[checkpoint,earlystop])

        #### EVAL ####

        model.load_weights(filepath)
        # model.save(filepath)
        for wr in [0,1,2,3]:
            metrics_model = model.evaluate(x=X_test[np.where(wr_persistence == wr)[0]],
                                           y=y_test[np.where(wr_persistence == wr)[0]])
            acc_weeks_model[iweek,wr] = metrics_model[1]
            loss_weeks_model[iweek,wr] = metrics_model[0]
            acc_weeks_persistence[iweek,wr] = accuracy_score(y_test[np.where(wr_persistence == wr)[0]],
                                             serie_wr_persistence_categorical[np.where(wr_persistence == wr)[0]])
            loss_weeks_persistence[iweek,wr] = log_loss(y_test[np.where(wr_persistence == wr)[0]],
                                        serie_wr_persistence_categorical[np.where(wr_persistence == wr)[0]])
            
#         print('loss/acc model')
#         print(metrics_model)
#         print('loss/acc persistence')
#         print([loss_persistence,acc_persistence])

#         loss_weeks_model.append(loss_temp)
#         loss_weeks_persistence.append(loss_persistence)
#         acc_weeks_model.append(acc_temp)
#         acc_weeks_persistence.append(acc_persistence)
    ### PLOT METRICS ###
    plt.figure(figsize=(8,5))

    plt.title(variable.upper(),fontsize=13)

    plt.plot(np.arange(8),acc_weeks_model[:,0],label = 'Alaskan Ridge')
    plt.scatter(np.arange(8),acc_weeks_model[:,0])
    plt.plot(np.arange(8),acc_weeks_model[:,1],label = 'Greenland High')
    plt.scatter(np.arange(8),acc_weeks_model[:,1])
    plt.plot(np.arange(8),acc_weeks_model[:,2],label = 'West Coast High')
    plt.scatter(np.arange(8),acc_weeks_model[:,2])
    plt.plot(np.arange(8),acc_weeks_model[:,3],label = 'Pacific Trough')
    plt.scatter(np.arange(8),acc_weeks_model[:,3])

    plt.legend(ncol=2,fontsize=11)
    plt.ylabel('Accuracy [%]\nTesting Sample',fontsize=12)
    plt.xticks(np.arange(8),['Week 1','Week 2','Week 3','Week 4','Week 5','Week 6','Week 7','Week 8'],fontsize=12)
    plt.xlabel('Lead time',fontsize=12)
    plt.yticks(fontsize=12)
    # plt.xlim(0,7)
    path_figures = '/glade/u/home/jhayron/WeatherRegimes/Figures/Metrics4DifferentRegimes/'
    plt.savefig(f'{path_figures}ACC_WR_{variable}.png',bbox_inches='tight')
    plt.close('all')
    
    
    ### 2. 
    plt.figure(figsize=(8,5))

    plt.title(variable.upper(),fontsize=13)

    plt.plot(np.arange(8),loss_weeks_model[:,0],label = 'Alaskan Ridge')
    plt.scatter(np.arange(8),loss_weeks_model[:,0])
    plt.plot(np.arange(8),loss_weeks_model[:,1],label = 'Greenland High')
    plt.scatter(np.arange(8),loss_weeks_model[:,1])
    plt.plot(np.arange(8),loss_weeks_model[:,2],label = 'West Coast High')
    plt.scatter(np.arange(8),loss_weeks_model[:,2])
    plt.plot(np.arange(8),loss_weeks_model[:,3],label = 'Pacific Trough')
    plt.scatter(np.arange(8),loss_weeks_model[:,3])

    plt.legend(ncol=2,fontsize=11)
    plt.ylabel('Categorical Cross-Entropy\nTesting Sample',fontsize=12)
    plt.xticks(np.arange(8),['Week 1','Week 2','Week 3','Week 4','Week 5','Week 6','Week 7','Week 8'],fontsize=12)
    plt.xlabel('Lead time',fontsize=12)
    plt.yticks(fontsize=12)
    # plt.xlim(0,7)
    path_figures = '/glade/u/home/jhayron/WeatherRegimes/Figures/Metrics4DifferentRegimes/'
    plt.savefig(f'{path_figures}LOSS_WR_{variable}.png',bbox_inches='tight')
    plt.close('all')
    ### SAVE METRICS ###
# Out:
# ********************************************************************************************
# z500
# ********************************************************************************************
# week2
# 5/5 [==============================] - 0s 16ms/step - loss: 1.1517 - accuracy: 0.5000
# 4/4 [==============================] - 0s 16ms/step - loss: 1.2951 - accuracy: 0.4159
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2171 - accuracy: 0.4453
# 5/5 [==============================] - 0s 16ms/step - loss: 1.3000 - accuracy: 0.4620
# week3
# 5/5 [==============================] - 0s 7ms/step - loss: 1.3983 - accuracy: 0.3141
# 4/4 [==============================] - 0s 6ms/step - loss: 1.3626 - accuracy: 0.2832
# 1/4 [======>.......................] - ETA: 0s - loss: 1.2676 - accuracy: 0.3125WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0051s vs `on_test_batch_end` time: 0.0173s). Check your callbacks.
# 4/4 [==============================] - 0s 21ms/step - loss: 1.3652 - accuracy: 0.2969
# 5/5 [==============================] - 0s 7ms/step - loss: 1.3801 - accuracy: 0.3165
# week4
# 5/5 [==============================] - 0s 8ms/step - loss: 1.4388 - accuracy: 0.2885
# 4/4 [==============================] - 0s 7ms/step - loss: 1.3281 - accuracy: 0.3186
# 1/4 [======>.......................] - ETA: 0s - loss: 1.3117 - accuracy: 0.3438WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0051s vs `on_test_batch_end` time: 0.0221s). Check your callbacks.
# 4/4 [==============================] - 0s 26ms/step - loss: 1.4273 - accuracy: 0.2734
# 5/5 [==============================] - 0s 7ms/step - loss: 1.3104 - accuracy: 0.3671
# week5
# 5/5 [==============================] - 0s 7ms/step - loss: 1.3934 - accuracy: 0.2692
# 4/4 [==============================] - 0s 6ms/step - loss: 1.3698 - accuracy: 0.3628
# 4/4 [==============================] - 0s 19ms/step - loss: 1.4004 - accuracy: 0.3594
# 5/5 [==============================] - 0s 7ms/step - loss: 1.3911 - accuracy: 0.3418
# week6
# 5/5 [==============================] - 0s 7ms/step - loss: 1.3529 - accuracy: 0.2949
# 4/4 [==============================] - 0s 6ms/step - loss: 1.3769 - accuracy: 0.3274
# 1/4 [======>.......................] - ETA: 0s - loss: 1.3341 - accuracy: 0.2812WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0050s vs `on_test_batch_end` time: 0.0153s). Check your callbacks.
# 4/4 [==============================] - 0s 23ms/step - loss: 1.4055 - accuracy: 0.2969
# 5/5 [==============================] - 0s 7ms/step - loss: 1.3765 - accuracy: 0.3481
# week7
# 5/5 [==============================] - 0s 7ms/step - loss: 1.4046 - accuracy: 0.2179
# 4/4 [==============================] - 0s 6ms/step - loss: 1.4016 - accuracy: 0.3363
# 1/4 [======>.......................] - ETA: 0s - loss: 1.3501 - accuracy: 0.2812WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0054s vs `on_test_batch_end` time: 0.0217s). Check your callbacks.
# 4/4 [==============================] - 0s 26ms/step - loss: 1.3863 - accuracy: 0.2500
# 5/5 [==============================] - 0s 7ms/step - loss: 1.3664 - accuracy: 0.3165
# week8
# 5/5 [==============================] - 0s 7ms/step - loss: 1.4310 - accuracy: 0.2628
# 4/4 [==============================] - 0s 6ms/step - loss: 1.4476 - accuracy: 0.2566
# 1/4 [======>.......................] - ETA: 0s - loss: 1.3820 - accuracy: 0.2500WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0049s vs `on_test_batch_end` time: 0.0200s). Check your callbacks.
# 4/4 [==============================] - 0s 26ms/step - loss: 1.4035 - accuracy: 0.2578
# 5/5 [==============================] - 0s 7ms/step - loss: 1.3882 - accuracy: 0.2722
# week9
# 5/5 [==============================] - 0s 7ms/step - loss: 1.4348 - accuracy: 0.2821
# 4/4 [==============================] - 0s 6ms/step - loss: 1.3922 - accuracy: 0.3274
# 1/4 [======>.......................] - ETA: 0s - loss: 1.3750 - accuracy: 0.2500WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0052s vs `on_test_batch_end` time: 0.0200s). Check your callbacks.
# 4/4 [==============================] - 0s 24ms/step - loss: 1.4369 - accuracy: 0.2578
# 5/5 [==============================] - 0s 7ms/step - loss: 1.3841 - accuracy: 0.3101
# ********************************************************************************************
# olr
# ********************************************************************************************
# week2
# 5/5 [==============================] - 0s 7ms/step - loss: 1.2074 - accuracy: 0.4295
# 4/4 [==============================] - 0s 6ms/step - loss: 1.3314 - accuracy: 0.3628
# 1/4 [======>.......................] - ETA: 0s - loss: 1.0796 - accuracy: 0.3750WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0050s vs `on_test_batch_end` time: 0.0153s). Check your callbacks.
# 4/4 [==============================] - 0s 24ms/step - loss: 1.3039 - accuracy: 0.3359
# 5/5 [==============================] - 0s 7ms/step - loss: 1.3607 - accuracy: 0.3924
# week3
# 5/5 [==============================] - 0s 7ms/step - loss: 1.4106 - accuracy: 0.2756
# 4/4 [==============================] - 0s 6ms/step - loss: 1.3527 - accuracy: 0.3628
# 4/4 [==============================] - 0s 23ms/step - loss: 1.3694 - accuracy: 0.2891
# 5/5 [==============================] - 0s 7ms/step - loss: 1.4107 - accuracy: 0.2532
# week4
# 5/5 [==============================] - 0s 7ms/step - loss: 1.4146 - accuracy: 0.2628
# 4/4 [==============================] - 0s 6ms/step - loss: 1.3508 - accuracy: 0.3540
# 4/4 [==============================] - 0s 19ms/step - loss: 1.3859 - accuracy: 0.2812
# 5/5 [==============================] - 0s 7ms/step - loss: 1.3065 - accuracy: 0.3671
# week5
# 5/5 [==============================] - 0s 7ms/step - loss: 1.4250 - accuracy: 0.2436
# 4/4 [==============================] - 0s 7ms/step - loss: 1.3674 - accuracy: 0.2832
# 1/4 [======>.......................] - ETA: 0s - loss: 1.2907 - accuracy: 0.3750WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0049s vs `on_test_batch_end` time: 0.0214s). Check your callbacks.
# 4/4 [==============================] - 0s 24ms/step - loss: 1.4120 - accuracy: 0.2812
# 5/5 [==============================] - 0s 7ms/step - loss: 1.3782 - accuracy: 0.3608
# week6
# 5/5 [==============================] - 0s 8ms/step - loss: 1.3524 - accuracy: 0.3846
# 4/4 [==============================] - 0s 6ms/step - loss: 1.3993 - accuracy: 0.3009
# 1/4 [======>.......................] - ETA: 0s - loss: 1.3251 - accuracy: 0.3125WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0051s vs `on_test_batch_end` time: 0.0222s). Check your callbacks.
# 4/4 [==============================] - 0s 26ms/step - loss: 1.4221 - accuracy: 0.2578
# 5/5 [==============================] - 0s 7ms/step - loss: 1.3471 - accuracy: 0.3418
# week7
# 5/5 [==============================] - 0s 7ms/step - loss: 1.4240 - accuracy: 0.3205
# 4/4 [==============================] - 0s 6ms/step - loss: 1.3995 - accuracy: 0.3097
# 1/4 [======>.......................] - ETA: 0s - loss: 1.3817 - accuracy: 0.2500WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0051s vs `on_test_batch_end` time: 0.0201s). Check your callbacks.
# 4/4 [==============================] - 0s 26ms/step - loss: 1.4201 - accuracy: 0.2891
# 5/5 [==============================] - 0s 7ms/step - loss: 1.3669 - accuracy: 0.3481
# week8
# 5/5 [==============================] - 0s 7ms/step - loss: 1.4223 - accuracy: 0.2692
# 4/4 [==============================] - 0s 6ms/step - loss: 1.4018 - accuracy: 0.2301
# 4/4 [==============================] - 0s 19ms/step - loss: 1.3837 - accuracy: 0.2969
# 5/5 [==============================] - 0s 7ms/step - loss: 1.3614 - accuracy: 0.3481
# week9
# 5/5 [==============================] - 0s 12ms/step - loss: 1.3966 - accuracy: 0.2821
# 4/4 [==============================] - 0s 7ms/step - loss: 1.3763 - accuracy: 0.3628
# 4/4 [==============================] - 0s 14ms/step - loss: 1.3904 - accuracy: 0.2656
# 5/5 [==============================] - 0s 13ms/step - loss: 1.3729 - accuracy: 0.3101
# ********************************************************************************************
# sst
# ********************************************************************************************
# week2
# 5/5 [==============================] - 0s 7ms/step - loss: 1.4312 - accuracy: 0.2692
# 4/4 [==============================] - 0s 6ms/step - loss: 1.5069 - accuracy: 0.2566
# 4/4 [==============================] - 0s 22ms/step - loss: 1.4253 - accuracy: 0.2734
# 5/5 [==============================] - 0s 7ms/step - loss: 1.3151 - accuracy: 0.4051
# week3
# 5/5 [==============================] - 0s 7ms/step - loss: 1.4031 - accuracy: 0.2628
# 4/4 [==============================] - 0s 6ms/step - loss: 1.3941 - accuracy: 0.2478
# 1/4 [======>.......................] - ETA: 0s - loss: 1.3339 - accuracy: 0.2500WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0051s vs `on_test_batch_end` time: 0.0222s). Check your callbacks.
# 4/4 [==============================] - 0s 26ms/step - loss: 1.3634 - accuracy: 0.2734
# 5/5 [==============================] - 0s 7ms/step - loss: 1.3321 - accuracy: 0.3481
# week4
# 5/5 [==============================] - 0s 7ms/step - loss: 1.4193 - accuracy: 0.2115
# 4/4 [==============================] - 0s 6ms/step - loss: 1.3512 - accuracy: 0.3540
# 1/4 [======>.......................] - ETA: 0s - loss: 1.3647 - accuracy: 0.1875WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0049s vs `on_test_batch_end` time: 0.0190s). Check your callbacks.
# 4/4 [==============================] - 0s 23ms/step - loss: 1.3920 - accuracy: 0.2266
# 5/5 [==============================] - 0s 7ms/step - loss: 1.3267 - accuracy: 0.3481
# week5
# 5/5 [==============================] - 0s 7ms/step - loss: 1.3916 - accuracy: 0.2308
# 4/4 [==============================] - 0s 6ms/step - loss: 1.3695 - accuracy: 0.2743
# 1/4 [======>.......................] - ETA: 0s - loss: 1.3557 - accuracy: 0.4062WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0050s vs `on_test_batch_end` time: 0.0177s). Check your callbacks.
# 4/4 [==============================] - 0s 23ms/step - loss: 1.3750 - accuracy: 0.2891
# 5/5 [==============================] - 0s 7ms/step - loss: 1.3277 - accuracy: 0.3987
# week6
# 5/5 [==============================] - 0s 8ms/step - loss: 1.3918 - accuracy: 0.2885
# 4/4 [==============================] - 0s 6ms/step - loss: 1.3909 - accuracy: 0.2655
# 4/4 [==============================] - 0s 17ms/step - loss: 1.4183 - accuracy: 0.2734
# 5/5 [==============================] - 0s 7ms/step - loss: 1.3193 - accuracy: 0.3861
# week7
# 5/5 [==============================] - 0s 7ms/step - loss: 1.3850 - accuracy: 0.2949
# 4/4 [==============================] - 0s 6ms/step - loss: 1.4140 - accuracy: 0.2035
# 4/4 [==============================] - 0s 19ms/step - loss: 1.3980 - accuracy: 0.3047
# 5/5 [==============================] - 0s 7ms/step - loss: 1.3306 - accuracy: 0.3671
# week8
# 5/5 [==============================] - 0s 10ms/step - loss: 1.3945 - accuracy: 0.2756
# 4/4 [==============================] - 0s 6ms/step - loss: 1.4014 - accuracy: 0.2035
# 1/4 [======>.......................] - ETA: 0s - loss: 1.3337 - accuracy: 0.2812WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0049s vs `on_test_batch_end` time: 0.0219s). Check your callbacks.
# 4/4 [==============================] - 0s 24ms/step - loss: 1.3684 - accuracy: 0.2812
# 5/5 [==============================] - 0s 7ms/step - loss: 1.3477 - accuracy: 0.3544
# week9
# 5/5 [==============================] - 0s 7ms/step - loss: 1.4110 - accuracy: 0.2821
# 4/4 [==============================] - 0s 6ms/step - loss: 1.3661 - accuracy: 0.3628
# 1/4 [======>.......................] - ETA: 0s - loss: 1.3743 - accuracy: 0.2500WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0052s vs `on_test_batch_end` time: 0.0160s). Check your callbacks.
# 4/4 [==============================] - 0s 25ms/step - loss: 1.4025 - accuracy: 0.2656
# 5/5 [==============================] - 0s 7ms/step - loss: 1.3655 - accuracy: 0.3101
# ********************************************************************************************
# u10
# ********************************************************************************************
# week2
# 5/5 [==============================] - 0s 7ms/step - loss: 1.4367 - accuracy: 0.2692
# 4/4 [==============================] - 0s 6ms/step - loss: 1.3635 - accuracy: 0.3628
# 1/4 [======>.......................] - ETA: 0s - loss: 1.2291 - accuracy: 0.5625WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0052s vs `on_test_batch_end` time: 0.0221s). Check your callbacks.
# 4/4 [==============================] - 0s 26ms/step - loss: 1.4157 - accuracy: 0.2812
# 5/5 [==============================] - 0s 7ms/step - loss: 1.3818 - accuracy: 0.3165
# week3
# 5/5 [==============================] - 0s 7ms/step - loss: 1.3986 - accuracy: 0.3269
# 4/4 [==============================] - 0s 6ms/step - loss: 1.3834 - accuracy: 0.3186
# 1/4 [======>.......................] - ETA: 0s - loss: 1.2640 - accuracy: 0.4062WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0052s vs `on_test_batch_end` time: 0.0231s). Check your callbacks.
# 4/4 [==============================] - 0s 26ms/step - loss: 1.3961 - accuracy: 0.2500
# 5/5 [==============================] - 0s 7ms/step - loss: 1.3925 - accuracy: 0.2848
# week4
# 5/5 [==============================] - 0s 7ms/step - loss: 1.4152 - accuracy: 0.2821
# 4/4 [==============================] - 0s 6ms/step - loss: 1.3766 - accuracy: 0.2920
# 1/4 [======>.......................] - ETA: 0s - loss: 1.3331 - accuracy: 0.3438WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0049s vs `on_test_batch_end` time: 0.0214s). Check your callbacks.
# 4/4 [==============================] - 0s 26ms/step - loss: 1.4014 - accuracy: 0.2656
# 5/5 [==============================] - 0s 7ms/step - loss: 1.3661 - accuracy: 0.3038
# week5
# 5/5 [==============================] - 0s 7ms/step - loss: 1.4067 - accuracy: 0.2436
# 4/4 [==============================] - 0s 6ms/step - loss: 1.3690 - accuracy: 0.3009
# 4/4 [==============================] - 0s 15ms/step - loss: 1.4015 - accuracy: 0.3281
# 5/5 [==============================] - 0s 7ms/step - loss: 1.3641 - accuracy: 0.3418
# week6
# 5/5 [==============================] - 0s 7ms/step - loss: 1.3819 - accuracy: 0.2885
# 4/4 [==============================] - 0s 6ms/step - loss: 1.4041 - accuracy: 0.2655
# 1/4 [======>.......................] - ETA: 0s - loss: 1.4148 - accuracy: 0.3125WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0051s vs `on_test_batch_end` time: 0.0202s). Check your callbacks.
# 4/4 [==============================] - 0s 27ms/step - loss: 1.4608 - accuracy: 0.2734
# 5/5 [==============================] - 0s 7ms/step - loss: 1.3521 - accuracy: 0.3861
# week7
# 5/5 [==============================] - 0s 7ms/step - loss: 1.3934 - accuracy: 0.3013
# 4/4 [==============================] - 0s 6ms/step - loss: 1.4109 - accuracy: 0.2301
# 1/4 [======>.......................] - ETA: 0s - loss: 1.3601 - accuracy: 0.3438WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0051s vs `on_test_batch_end` time: 0.0222s). Check your callbacks.
# 4/4 [==============================] - 0s 26ms/step - loss: 1.4830 - accuracy: 0.2344
# 5/5 [==============================] - 0s 7ms/step - loss: 1.3909 - accuracy: 0.3291
# week8
# 5/5 [==============================] - 0s 7ms/step - loss: 1.4464 - accuracy: 0.2628
# 4/4 [==============================] - 0s 6ms/step - loss: 1.4320 - accuracy: 0.2124
# 4/4 [==============================] - 0s 19ms/step - loss: 1.4230 - accuracy: 0.3203
# 5/5 [==============================] - 0s 7ms/step - loss: 1.4102 - accuracy: 0.2975
# week9
# 5/5 [==============================] - 0s 7ms/step - loss: 1.3976 - accuracy: 0.2949
# 4/4 [==============================] - 0s 6ms/step - loss: 1.3578 - accuracy: 0.3363
# 1/4 [======>.......................] - ETA: 0s - loss: 1.3629 - accuracy: 0.3438WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0050s vs `on_test_batch_end` time: 0.0130s). Check your callbacks.
# 4/4 [==============================] - 0s 20ms/step - loss: 1.4197 - accuracy: 0.2891
# 5/5 [==============================] - 0s 7ms/step - loss: 1.3783 - accuracy: 0.3354
# ********************************************************************************************
# sm_region
# ********************************************************************************************
# week2
# 5/5 [==============================] - 0s 5ms/step - loss: 1.4168 - accuracy: 0.2436
# 4/4 [==============================] - 0s 5ms/step - loss: 1.4105 - accuracy: 0.2566
# 4/4 [==============================] - 0s 10ms/step - loss: 1.3709 - accuracy: 0.2500
# 5/5 [==============================] - 0s 5ms/step - loss: 1.3484 - accuracy: 0.4177
# week3
# 5/5 [==============================] - 0s 5ms/step - loss: 1.3950 - accuracy: 0.2436
# 4/4 [==============================] - 0s 3ms/step - loss: 1.3746 - accuracy: 0.3628
# 4/4 [==============================] - 0s 7ms/step - loss: 1.3872 - accuracy: 0.3125
# 5/5 [==============================] - 0s 2ms/step - loss: 1.3772 - accuracy: 0.3228
# week4
# 5/5 [==============================] - 0s 12ms/step - loss: 1.4041 - accuracy: 0.2051
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3708 - accuracy: 0.4336
# 4/4 [==============================] - 0s 17ms/step - loss: 1.4008 - accuracy: 0.2422
# 5/5 [==============================] - 0s 2ms/step - loss: 1.3660 - accuracy: 0.3608
# week5
# 5/5 [==============================] - 0s 3ms/step - loss: 1.4039 - accuracy: 0.2244
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3687 - accuracy: 0.3894
# 1/4 [======>.......................] - ETA: 0s - loss: 1.3486 - accuracy: 0.3750WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0020s vs `on_test_batch_end` time: 0.0181s). Check your callbacks.
# 4/4 [==============================] - 0s 22ms/step - loss: 1.3851 - accuracy: 0.2734
# 5/5 [==============================] - 0s 2ms/step - loss: 1.3665 - accuracy: 0.3861
# week6
# 5/5 [==============================] - 0s 3ms/step - loss: 1.3893 - accuracy: 0.2500
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3843 - accuracy: 0.3451
# 1/4 [======>.......................] - ETA: 0s - loss: 1.4021 - accuracy: 0.2812WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0020s vs `on_test_batch_end` time: 0.0136s). Check your callbacks.
# 4/4 [==============================] - 0s 19ms/step - loss: 1.4170 - accuracy: 0.2109
# 5/5 [==============================] - 0s 2ms/step - loss: 1.3514 - accuracy: 0.4620
# week7
# 5/5 [==============================] - 0s 3ms/step - loss: 1.3827 - accuracy: 0.2949
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3957 - accuracy: 0.2035
# 4/4 [==============================] - 0s 7ms/step - loss: 1.3847 - accuracy: 0.3047
# 5/5 [==============================] - 0s 2ms/step - loss: 1.3630 - accuracy: 0.3671
# week8
# 5/5 [==============================] - 0s 3ms/step - loss: 1.3914 - accuracy: 0.2949
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3936 - accuracy: 0.2301
# 4/4 [==============================] - 0s 7ms/step - loss: 1.3712 - accuracy: 0.3047
# 5/5 [==============================] - 0s 2ms/step - loss: 1.3680 - accuracy: 0.3544
# week9
# 5/5 [==============================] - 0s 3ms/step - loss: 1.3924 - accuracy: 0.2821
# 4/4 [==============================] - 0s 3ms/step - loss: 1.3725 - accuracy: 0.3628
# 1/4 [======>.......................] - ETA: 0s - loss: 1.3725 - accuracy: 0.2500WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0021s vs `on_test_batch_end` time: 0.0199s). Check your callbacks.
# 4/4 [==============================] - 0s 21ms/step - loss: 1.3858 - accuracy: 0.2656
# 5/5 [==============================] - 0s 2ms/step - loss: 1.3768 - accuracy: 0.3101
# ********************************************************************************************
# st_region
# ********************************************************************************************
# week2
# 5/5 [==============================] - 0s 2ms/step - loss: 1.4168 - accuracy: 0.2372
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4008 - accuracy: 0.2566
# 1/4 [======>.......................] - ETA: 0s - loss: 1.3598 - accuracy: 0.3125WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0021s vs `on_test_batch_end` time: 0.0200s). Check your callbacks.
# 4/4 [==============================] - 0s 22ms/step - loss: 1.3764 - accuracy: 0.2891
# 5/5 [==============================] - 0s 2ms/step - loss: 1.3477 - accuracy: 0.4241
# week3
# 5/5 [==============================] - 0s 3ms/step - loss: 1.4074 - accuracy: 0.2564
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3896 - accuracy: 0.3274
# 1/4 [======>.......................] - ETA: 0s - loss: 1.3442 - accuracy: 0.4375WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0021s vs `on_test_batch_end` time: 0.0209s). Check your callbacks.
# 4/4 [==============================] - 0s 22ms/step - loss: 1.4017 - accuracy: 0.3047
# 5/5 [==============================] - 0s 2ms/step - loss: 1.3804 - accuracy: 0.3101
# week4
# 5/5 [==============================] - 0s 3ms/step - loss: 1.4050 - accuracy: 0.2179
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3677 - accuracy: 0.3894
# 4/4 [==============================] - 0s 7ms/step - loss: 1.3993 - accuracy: 0.2578
# 5/5 [==============================] - 0s 2ms/step - loss: 1.3670 - accuracy: 0.3354
# week5
# 5/5 [==============================] - 0s 3ms/step - loss: 1.3959 - accuracy: 0.2244
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3640 - accuracy: 0.3894
# 4/4 [==============================] - 0s 12ms/step - loss: 1.3873 - accuracy: 0.2734
# 5/5 [==============================] - 0s 2ms/step - loss: 1.3610 - accuracy: 0.3861
# week6
# 5/5 [==============================] - 0s 3ms/step - loss: 1.3801 - accuracy: 0.2885
# 4/4 [==============================] - 0s 3ms/step - loss: 1.3847 - accuracy: 0.2655
# 1/4 [======>.......................] - ETA: 0s - loss: 1.3784 - accuracy: 0.3125WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0020s vs `on_test_batch_end` time: 0.0151s). Check your callbacks.
# 4/4 [==============================] - 0s 20ms/step - loss: 1.3914 - accuracy: 0.2734
# 5/5 [==============================] - 0s 2ms/step - loss: 1.3609 - accuracy: 0.3861
# week7
# 5/5 [==============================] - 0s 3ms/step - loss: 1.3800 - accuracy: 0.2949
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4045 - accuracy: 0.2035
# 4/4 [==============================] - 0s 7ms/step - loss: 1.3835 - accuracy: 0.3125
# 5/5 [==============================] - 0s 2ms/step - loss: 1.3723 - accuracy: 0.3671
# week8
# 5/5 [==============================] - 0s 3ms/step - loss: 1.3977 - accuracy: 0.2949
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3986 - accuracy: 0.2301
# 1/4 [======>.......................] - ETA: 0s - loss: 1.3439 - accuracy: 0.3750WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0020s vs `on_test_batch_end` time: 0.0145s). Check your callbacks.
# 4/4 [==============================] - 0s 20ms/step - loss: 1.3726 - accuracy: 0.3047
# 5/5 [==============================] - 0s 2ms/step - loss: 1.3672 - accuracy: 0.3544
# week9
# 5/5 [==============================] - 0s 3ms/step - loss: 1.3927 - accuracy: 0.2821
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3746 - accuracy: 0.3628
# 4/4 [==============================] - 0s 7ms/step - loss: 1.3885 - accuracy: 0.2656
# 5/5 [==============================] - 0s 2ms/step - loss: 1.3783 - accuracy: 0.3101

# %%
    ### PLOT METRICS ###
    plt.figure(figsize=(8,5))

    plt.title('Persistence',fontsize=13)

    plt.plot(np.arange(8),acc_weeks_persistence[:,0],label = 'Alaskan Ridge')
    plt.scatter(np.arange(8),acc_weeks_persistence[:,0])
    plt.plot(np.arange(8),acc_weeks_persistence[:,1],label = 'Greenland High')
    plt.scatter(np.arange(8),acc_weeks_persistence[:,1])
    plt.plot(np.arange(8),acc_weeks_persistence[:,2],label = 'West Coast High')
    plt.scatter(np.arange(8),acc_weeks_persistence[:,2])
    plt.plot(np.arange(8),acc_weeks_persistence[:,3],label = 'Pacific Trough')
    plt.scatter(np.arange(8),acc_weeks_persistence[:,3])

    plt.legend(ncol=2,fontsize=11)
    plt.ylabel('Accuracy [%]\nTesting Sample',fontsize=12)
    plt.xticks(np.arange(8),['Week 1','Week 2','Week 3','Week 4','Week 5','Week 6','Week 7','Week 8'],fontsize=12)
    plt.xlabel('Lead time',fontsize=12)
    plt.yticks(fontsize=12)
    # plt.xlim(0,7)
    path_figures = '/glade/u/home/jhayron/WeatherRegimes/Figures/Metrics4DifferentRegimes/'
    plt.savefig(f'{path_figures}ACC_WR_Persistence.png',bbox_inches='tight')
    
    
    
    ### 2. 
    plt.figure(figsize=(8,5))

    plt.title('Persistence',fontsize=13)

    plt.plot(np.arange(8),loss_weeks_persistence[:,0],label = 'Alaskan Ridge')
    plt.scatter(np.arange(8),loss_weeks_persistence[:,0])
    plt.plot(np.arange(8),loss_weeks_persistence[:,1],label = 'Greenland High')
    plt.scatter(np.arange(8),loss_weeks_persistence[:,1])
    plt.plot(np.arange(8),loss_weeks_persistence[:,2],label = 'West Coast High')
    plt.scatter(np.arange(8),loss_weeks_persistence[:,2])
    plt.plot(np.arange(8),loss_weeks_persistence[:,3],label = 'Pacific Trough')
    plt.scatter(np.arange(8),loss_weeks_persistence[:,3])

    plt.legend(ncol=2,fontsize=11)
    plt.ylabel('Categorical Cross-Entropy\nTesting Sample',fontsize=12)
    plt.xticks(np.arange(8),['Week 1','Week 2','Week 3','Week 4','Week 5','Week 6','Week 7','Week 8'],fontsize=12)
    plt.xlabel('Lead time',fontsize=12)
    plt.yticks(fontsize=12)
    # plt.xlim(0,7)
    path_figures = '/glade/u/home/jhayron/WeatherRegimes/Figures/Metrics4DifferentRegimes/'
    plt.savefig(f'{path_figures}LOSS_WR_Persistence.png',bbox_inches='tight')
